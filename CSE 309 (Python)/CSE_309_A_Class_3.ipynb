# %% [markdown]
# # List

# %%
L = [1, 2, 3, 4, 5, 10, 20]
type(L)
# Out:
# list

# %%
L[0]
# Out:
# 1

# %%
L[6]
# Out:
# 20

# %%
L
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
L[-1]
# Out:
# 20

# %%
L[len(L) - 1]
# Out:
# 20

# %%
L2 = [L[2], L[3], L[4]]
L2
# Out:
# [3, 4, 5]

# %%
L
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
'''
for(int i=2; i<5; i++){
    print(L[i])
}
'''

# %%
L3 = L[ 2 : 5 ]
L3
# Out:
# [3, 4, 5]

# %%
L[ 2 : -1 ]
# Out:
# [3, 4, 5, 10]

# %%
L[ 2 : 0 ]
# Out:
# []

# %%
'''
for(int i=0; i<len(L); i+=2){
    print(L[i])
}
'''

# %%
L[ 0 : len(L) ]
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
L[ : ]
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
L[ 2: ]
# Out:
# [3, 4, 5, 10, 20]

# %%
L[0 : len(L) : 1]
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
L[0 : len(L) : 2]  #List[ starting index : ending index+1 : increment ]
# Out:
# [1, 3, 5, 20]

# %%
L[ :  : 2]
# Out:
# [1, 3, 5, 20]

# %%
L[ : : ]
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
L[4 : 1 : -1]
# Out:
# [5, 4, 3]

# %%
for (int i=4; i>1 ; i-=1)

# %%
L[ 0 : len(L) : -1]

'''
for(i=0; i>len(L) ; i-=1)
'''
# Out:
# []

# %%
L[ len(L) : 0 : -1]

'''
for(i=len(L); i>0 ; i-=1)
'''
# Out:
# [20, 10, 5, 4, 3, 2]

# %%
L
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
L[ : : -1]
# Out:
# [20, 10, 5, 4, 3, 2, 1]
